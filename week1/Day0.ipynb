# %% [markdown]
# # MY FIRST NOTEBOOK

# %% [markdown]
# # What I did at day 0?
#
# ## Miniconda:
# - Installed Python (conda create -n py311 python=3.11);
# - Installed Jupyter notebook (pip install jupyter notebook);
# ## VSCode:
# - Installed VSCode extensions (Cntrl + Shift + X) Python and Jupyter
# - Connected conda environment to VSCode (Cntrl + Shift + P -> >Python: Select Interpreter);
# - Created my first notebook (Cntrl + Shift + P -> >Create: New Jupyter Notebook);
# - Figured it out how it works in Jupyter notebook and watched a video about it (https://www.youtube.com/watch?v=suAkMeWJ1yE);
#
# ## GIT:
# - Created a new repository (https://github.com/qv1nti/ds-learning) and pushed my files into main branch (git add . -> git commit -m "Day 0" -> git push)
#
# ## Kaggle:
# - Registered on Kaggle (https://www.kaggle.com/)

# %% [markdown]
# # CODE:

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # Questions:
#
# - Do I need to create repostitory on Git site or I need to do it in VSCode terminal?
# - I will work in 1 file for all month or I need to create a new one notebook every day?
